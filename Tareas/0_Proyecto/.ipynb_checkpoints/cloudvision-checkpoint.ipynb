# %% [markdown]
# ## <span style="color:#3182bd"><center>**Extraer Informacion escrita a mano**</center></span>

# %% [markdown]
# ## pasar pdf a imagen y recortarla
#
# Como los pdf escaneados no tienen la misma estructura, debemos realizarle el siguiente proceso para que la información tenga una misma estructura:
#
# 1 extraemos la pagina necesaria y la convertimos en imagen
#
# 2 se pasa la imagen a escala de grises, se detectan los bords del formato y se realiza un recore a la imagen y se redimenciona

# %%
import fitz  # PyMuPDF
import cv2
import numpy as np
import os


formatos_entrada = r"C:\Users\pc\OneDrive\Escritorio\OC_pdf\Formatos"
imagen_salida = r"C:\Users\pc\OneDrive\Escritorio\OC_pdf\carpeta_salida"
os.makedirs(imagen_salida, exist_ok=True)

pdf_lista = [f for f in os.listdir(formatos_entrada) if f.endswith(".pdf")]

for idx, pdf_file in enumerate(pdf_lista, start=1):

    pdf_path = os.path.join(formatos_entrada, pdf_file)
    pdf_documento = fitz.open(pdf_path)
    primer_pagina = pdf_documento.load_page(0)
    image = primer_pagina.get_pixmap(matrix=fitz.Matrix(300/72, 300/72))
    image_filename = f"pagina_{idx}.png"
    image_path = os.path.join(imagen_salida, image_filename)
    image.save(image_path, "png")
    pdf_documento.close()
    
    image = cv2.imread(image_path)
    
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    edges = cv2.Canny(gray, 50, 150, apertureSize=3)


    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=100, maxLineGap=10)
    
    if lines is not None:
        mask = np.zeros(gray.shape, dtype=np.uint8)

        for line in lines:
            x1, y1, x2, y2 = line[0]
            
            cv2.line(mask, (x1, y1), (x2, y2), 255, 2)

        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            x, y, w, h = cv2.boundingRect(largest_contour)

            
            imagen_recortada = image[y:y + h, x:x + w]

            
            nuevo_ancho = 1629
            nuevo_alto = 1236
            imagen_recortada = cv2.resize(imagen_recortada, (nuevo_ancho, nuevo_alto))

           
            imagen_mejorada = cv2.filter2D(imagen_recortada, -1, np.array([[-1, -1, -1],
                                                                         [-1,  10, -1],
                                                                         [-1, -1, -1]]))

            
            nombre_imagen_mejorada = os.path.join(imagen_salida, image_filename)

           
            cv2.imwrite(nombre_imagen_mejorada, imagen_mejorada)

print("Procesamiento de PDFs completado.")
# Out:
# Procesamiento de PDFs completado.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = [
    r"C:\Users\pc\OneDrive\Escritorio\OC_pdf\imagen2.jpg",
    r"C:\Users\pc\OneDrive\Escritorio\OC_pdf\carpeta_salida\pagina_4.png"
]

num_images = len(image_paths)
fig, axes = plt.subplots(1, num_images, figsize=(10, 5))

# Cargar y mostrar las imágenes
for i, image_path in enumerate(image_paths):
    image = mpimg.imread(image_path)
    axes[i].imshow(image)
    axes[i].set_title(f'Imagen {i+1}')
    axes[i].axis('off')

plt.show()

# %% [markdown]
# ## COORDENADAS

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Carga la imagen
image = mpimg.imread("imagen_mejorada.jpg")

# Muestra la imagen en una ventana interactiva
plt.imshow(image)
plt.title("Haz clic en la imagen")

# Define una función de devolución de llamada para obtener las coordenadas del clic
def obtener_coordenadas(event):
    if event.button == 1:  # Comprueba si se hizo clic con el botón izquierdo del ratón
        x, y = event.xdata, event.ydata
        print(f"Coordenadas: x={x}, y={y}")

# Conecta la función de devolución de llamada al evento de clic
plt.connect('button_press_event', obtener_coordenadas)

# Muestra la imagen en la ventana interactiva
plt.show()

# %%
#pip install google-cloud-vision

# %%
from google.cloud import vision
from google.oauth2 import service_account
import io
import os

# Ruta al archivo JSON de credenciales de servicio
credentials_path = r"C:\Users\pc\OneDrive\Escritorio\OC_pdf\ocr-extraer-texto-c42de34459bc.json"

# Inicializa el cliente de Google Cloud Vision
credentials = service_account.Credentials.from_service_account_file(credentials_path)
client = vision.ImageAnnotatorClient(credentials=credentials)

# Directorio que contiene las imágenes a procesar
input_directory = r"C:\Users\pc\OneDrive\Escritorio\OC_pdf\carpeta_salida"

# Define las coordenadas de las regiones de interés (ROI) y asigna un identificador único
regiones = [
    {"id": 1, "left_x": 6, "top_y": 127, "right_x": 748, "bottom_y": 252},
    {"id": 2, "left_x": 750, "top_y": 135, "right_x": 1107, "bottom_y": 252},
    {"id": 3, "left_x": 1114, "top_y": 138, "right_x": 1500, "bottom_y": 259},
    {"id": 4, "left_x": 1500, "top_y": 138, "right_x": 1622, "bottom_y": 243},
    
    {"id": 5, "left_x": 6, "top_y": 236, "right_x": 748, "bottom_y": 360},
    {"id": 6, "left_x": 750, "top_y": 243, "right_x": 1107, "bottom_y": 359},
    {"id": 7, "left_x": 1114, "top_y": 256, "right_x": 1500, "bottom_y": 345},
    {"id": 8, "left_x": 1500, "top_y": 248, "right_x": 1622, "bottom_y": 357},
    
    {"id": 9, "left_x": 6, "top_y": 347, "right_x": 748, "bottom_y": 455},
    {"id": 10, "left_x": 750, "top_y": 352, "right_x": 1107, "bottom_y": 457},
    {"id": 11, "left_x": 1114, "top_y": 354, "right_x": 1500, "bottom_y": 462},
    {"id": 12, "left_x": 1500, "top_y": 355, "right_x": 1622, "bottom_y": 462}
]
lista = []
for image_file in os.listdir(input_directory):
    image_path = os.path.join(input_directory, image_file)

    # Lee la imagen
    with io.open(image_path, 'rb') as image_file:
        content = image_file.read()

    # Crea una instancia de la imagen para Google Cloud Vision
    image = vision.Image(content=content)

    # Inicializa un diccionario para almacenar el texto por coordenadas
    texto_por_coordenadas = {}

    # Realiza la solicitud de OCR con Google Cloud Vision
    response = client.text_detection(image=image)
    texts = response.text_annotations

    # Procesa cada región de interés (ROI) y almacena el texto en el diccionario
    
    for region in regiones:
        region_id = region["id"]
        left_x, top_y, right_x, bottom_y = region["left_x"], region["top_y"], region["right_x"], region["bottom_y"]

        # Verifica si el texto está dentro de la región de interés
        texto_en_region = ""
        for text in texts:
            if left_x <= text.bounding_poly.vertices[0].x <= right_x and \
               top_y <= text.bounding_poly.vertices[0].y <= bottom_y:
                texto_en_region += text.description + " "

        texto_por_coordenadas[region_id] = texto_en_region.strip()

    # Imprime el texto por coordenadas para la imagen actual
    #print(f"Texto extraído de {image_file} por coordenadas:")
    
    for region_id, texto in texto_por_coordenadas.items():
        print(f"Región {region_id}: {texto}")
        lista.append(texto)
# Out:
# Región 1: Angelica Vannessa Ramirez Rubio
# Región 2: 11 12 92
# Región 3: 1072667399
# Región 4: ESPOS @
# Región 5: German Reina Bojaca
# Región 6: 11 03 59
# Región 7: 2994376
# Región 8: SUEGR @ O PADRE
# Región 9:
# Región 10:
# Región 11:
# Región 12: SUEGR @ O MADRE
# Región 1:
# Región 2:
# Región 3:
# Región 4: ESPOS @
# Región 5: Lourian Eliseo Buitrago Rodríguez
# Región 6: 12 02 1960
# Región 7: 19392593
# Región 8: SUEGR @ O PADRE
# Región 9: Angie Carolina Cardozo
# Región 10: 02 02 1979
# Región 11: 52536718
# Región 12: SUEGR @ O MADRE
# Región 1: M. Galuis Areualo
# Región 2: 06 1994
# Región 3: 1024555 254
# Región 4: ESPOS
# Región 5: Betsabe But sabe Carreño
# Región 6: 27 06 195339749473
# Región 7: .
# Región 8: SUEGRO
# Región 9:
# Región 10:
# Región 11:
# Región 12: SUEGRED
# Región 1:
# Región 2:
# Región 3:
# Región 4: PADRE
# Región 5: Andrea Paola Nustes Ovola
# Región 6: 03 01 1988
# Región 7: 1014 189 75 1
# Región 8: MADRE
# Región 9: Yisset Paola Tique Nustes
# Región 10: 22 08 2015
# Región 11: 1013 149 278
# Región 12: HERMANO
# Región 1: Um ba Morales 23/09/59
# Región 2:
# Región 3: 19.308.28O
# Región 4: PADRE
# Región 5: Norbolla Cruz Lequiacinion
# Región 6: 16 08 57.51.598.975
# Región 7: ,
# Región 8: MADRE
# Región 9:
# Región 10:
# Región 11:
# Región 12: HERMANO
# Región 1: Robén Danio Palacio Velasquez Lina
# Región 2: 8 01 1982
# Región 3: 712 713 44
# Región 4: PADRE
# Región 5: Lina Evoli Vallejo Arango
# Región 6: 18 / 12 1969
# Región 7: 48724557
# Región 8: MADRE
# Región 9: David Pinzon Vallejo
# Región 10: 19 03 1992
# Región 11: 1036639685
# Región 12: HERMANO
# Región 1: Gabstel Salcedo Lopez Gutierrez
# Región 2: 03 1975 10
# Región 3: 79669925
# Región 4: PADRE
# Región 5: Luz Dary Zamudio Gutierrez Andres folipe Salcedo Zamudio
# Región 6: 01 05 1975
# Región 7: 52261508
# Región 8: MADRE
# Región 9: Andres folipe Salcedo Zamudio
# Región 10: 18/04/1999 |
# Región 11: 1233694143
# Región 12: HERMANO
# Región 1: Tanu Andrea Bokoryou ? Suure ? Тами Bohorquez 7
# Región 2: 17 10 95
# Región 3: 1010226 015
# Región 4: ESPOS @
# Región 5:
# Región 6:
# Región 7:
# Región 8: SUEGR @ O PADRE
# Región 9: Maniol Benitez Tamayo os
# Región 10: 07 72
# Región 11: 52084009
# Región 12: SUEGR @ O MADRE
# Región 1: CELIS CAMILO PACZ FORERO
# Región 2: 25 02 1968
# Región 3: 11345 258
# Región 4: PADRE
# Región 5: XIMENA FINO RODRIGUEZ
# Región 6: 13 10 1984
# Región 7: 52999390
# Región 8: MADRE
# Región 9: JUAN SEBASTIAN PAC2 FINO
# Región 10: 04 2003
# Región 11: 1001051185
# Región 12: HERMANO

# %%
import pandas as pd

# Supongamos que tienes el diccionario texto_por_region con tu información
# Supongamos que cada valor del diccionario es una cadena de texto

# Obtener los valores del diccionario como una lista
datos = lista

# Dividir la lista de datos en grupos de cuatro elementos
num_columnas = 4
datos_agrupados = [datos[i:i + num_columnas] for i in range(0, len(datos), num_columnas)]

column_names = ["nombre", "fecha_nacimiento","id","parentesco"]  # Nombres de las columnas
df = pd.DataFrame(datos_agrupados, columns=column_names)

df['nombre'] = df['nombre'].astype(str)
df['parentesco'] = df['parentesco'].astype(str)

df['id'] = df['id'].str.replace(r'\D', '', regex=True)

df['fecha_nacimiento'] = df['fecha_nacimiento'].str.replace(r'\D', '', regex=True)

#df['fecha_nacimiento'] = df['fecha_nacimiento'].apply(lambda x: '19' + x if int(x[:2]) >= 50 else '20' + x)

# Convertir la columna 'Fecha' al formato de fecha deseado
#df['fecha_nacimiento'] = pd.to_datetime(df['fecha_nacimiento'], format='%Y%m%d', errors='coerce')


# Mostrar el DataFrame
df
# Out:
#                              nombre fecha_nacimiento          id  \
# 0   Angelica Vannessa Ramirez Rubio           111292  1072667399
# 1               German Reina Bojaca          2994376
# 2
# 3
# 4                          19392593
# 5                          52536718
# 6                       1024555 254
# 7                            SUEGRO
# 8                           SUEGRED
# 9                             PADRE                   1014189751
# 10        Yisset Paola Tique Nustes         22082015  1013149278
# 11           Um ba Morales 23/09/59                      1930828
# 12       Norbolla Cruz Lequiacinion
# 13
# 14                        8 01 1982         71271344
# 15                         48724557
# 16                       1036639685
# 17                         79669925
# 18                            MADRE                     18041999
# 19                          HERMANO                7      171095
# 20                          ESPOS @
# 21         Maniol Benitez Tamayo os             0772    52084009
# 22         CELIS CAMILO PACZ FORERO         25021968    11345258
# 23            XIMENA FINO RODRIGUEZ         52999390
# 24                          04 2003       1001051185
#
#                             parentesco
# 0                              ESPOS @
# 1
# 2
# 3    Lourian Eliseo Buitrago Rodríguez
# 4                           02 02 1979
# 5                              06 1994
# 6                                    .
# 7
# 8
# 9                                MADRE
# 10                             HERMANO
# 11                               PADRE
# 12
# 13  Robén Danio Palacio Velasquez Lina
# 14           Lina Evoli Vallejo Arango
# 15                          19 03 1992
# 16                          03 1975 10
# 17                            52261508
# 18                          1233694143
# 19                         1010226 015
# 20                     SUEGR @ O PADRE
# 21                     SUEGR @ O MADRE
# 22                               PADRE
# 23            JUAN SEBASTIAN PAC2 FINO
# 24                                None
